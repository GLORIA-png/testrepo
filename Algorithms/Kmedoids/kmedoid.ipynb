# %%
pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in c:\users\abhilash\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\abhilash\anaconda3\lib\site-packages (from scikit-learn-extra) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\abhilash\anaconda3\lib\site-packages (from scikit-learn-extra) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\abhilash\anaconda3\lib\site-packages (from scikit-learn-extra) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\abhilash\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abhilash\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn_extra.cluster import KMedoids
import matplotlib.pyplot as plt

# %%
# Generate random data
np.random.seed(0)
X = np.random.rand(100, 2)

# %%
# Define the number of clusters
k = 3

# %%
# Fit the KMedoids model to the data
kmedoids = KMedoids(n_clusters=k, random_state=0).fit(X)

# %%
# Get cluster centroids and labels
centroids = kmedoids.cluster_centers_
labels = kmedoids.labels_

# %%
# Plotting the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='X')
plt.title('KMedoids Clustering')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
