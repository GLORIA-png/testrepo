# %% [markdown]
# <a href="https://colab.research.google.com/github/GLORIA-png/testrepo/blob/main/_plotting_02_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('./Car_sales.csv',parse_dates=['Latest_Launch'])
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger                 NaN          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0    2012-02-02
# 1     70.3   192.9        3.517           17.2             25.0    2011-06-03
# 2     70.6   192.0        3.470           17.2             26.0    2012-01-04
# 3     71.4   196.6        3.850           18.0             22.0    2011-03-10
# 4     68.2   178.0        2.998           16.4             27.0    2011-10-08
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0    2011-09-21
# 153   69.3   185.9        3.208           17.9             25.0    2012-11-24
# 154   69.3   186.2        3.259           17.9             25.0    2011-06-25
# 155   71.5   185.7        3.601           18.5             23.0    2011-04-26
# 156   72.1   189.8        3.600           21.1             24.0    2011-11-14
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2                  NaN
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
#  15  Power_perf_factor    155 non-null    float64
# dtypes: datetime64[ns](1), float64(12), object(3)
# memory usage: 19.8+ KB

# %%
data.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# count   155.000000     156.000000       154.000000         155.000000
# mean      3.378026      17.951923        23.844156          77.043591
# std       0.630502       3.887921         4.282706          25.142664
# min       1.895000      10.300000        15.000000          23.276272
# 25%       2.971000      15.800000        21.000000          60.407707
# 50%       3.342000      17.200000        24.000000          72.030917
# 75%       3.799500      19.575000        26.000000          89.414878
# max       5.572000      32.000000        45.000000         188.144323

# %%
data.isnull().mean()* 100
# Out:
# Manufacturer           0.0
# Model                  0.0
# Sales_in_thousands     0.0
# __year_resale_value    0.0
# Vehicle_type           0.0
# Price_in_thousands     0.0
# Engine_size            0.0
# Horsepower             0.0
# Wheelbase              0.0
# Width                  0.0
# Length                 0.0
# Curb_weight            0.0
# Fuel_capacity          0.0
# Fuel_efficiency        0.0
# Latest_Launch          0.0
# Power_perf_factor      0.0
# dtype: float64

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %% [markdown]
# #### UNIVARIATE ANALYSIS

# %% [markdown]
# #### HISTOGRAM

# %%
plt.figure(figsize=(9,6))
plt.title('Histogram')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xticks(rotation=45)
sns.histplot(data=data,x='Sales_in_thousands',bins=50)
plt.show()

# %%
data.Sales_in_thousands.max()
# Out:
# 540.561

# %%
data.Sales_in_thousands.min()
# Out:
# 0.11

# %% [markdown]
# #### boxplot

# %%
sns.boxplot(data=data,x='Sales_in_thousands')
plt.show()

# %%
sns.boxplot(data=data,x='Sales_in_thousands',y='Vehicle_type')
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation=75)
sns.boxplot(data=data)
plt.show()

# %% [markdown]
# ### kde plot

# %%
sns.kdeplot(data=data.Sales_in_thousands)
plt.show()

# %%
sns.histplot(data=data)
plt.show();
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:160: UserWarning: The label '__year_resale_value' of <matplotlib.patches.Patch object at 0x7c999cf54fa0> starts with '_'. It is thus excluded from the legend.
#   ax_obj.legend(handles, labels, title=self.variables["hue"], **legend_kws)

# %% [markdown]
# ### line charts

# %%
plt.figure(figsize=(10,6))
plt.xlabel('__year_resale_value')
plt.ylabel('price')
plt.title('graph')
sns.lineplot(data=data,x='__year_resale_value',y='Price_in_thousands')
plt.show()

# %% [markdown]
# ### count plot

# %%
plt.figure(figsize=(16,5))
plt.xticks(rotation=45)
sns.countplot(data=data,x='Manufacturer')
plt.show()

# %% [markdown]
# ### area chart

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=45)
plt.stackplot(data.Manufacturer,data.Sales_in_thousands,labels='Sales_in_thousands')
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation=90)
plt.stackplot(data.Manufacturer,data.Sales_in_thousands,data.Price_in_thousands)
plt.show()

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ### horrizontal barchart

# %%
plt.figure(figsize=(6,12))
plt.xticks(rotation=45)
sns.barplot(data=data,x='Sales_in_thousands',y='Manufacturer')
plt.show()

# %% [markdown]
# ### vertical barplot

# %%
plt.figure(figsize=(12,4))
plt.xticks(rotation = 90)
sns.barplot(data=data, x='Manufacturer', y='Horsepower')
plt.show()

# %% [markdown]
# ### scatter plot

# %%
sns.scatterplot(data=data, x='Horsepower', y='Sales_in_thousands')
plt.show()

# %%
sns.scatterplot(data=data, x='Horsepower', y='Sales_in_thousands', hue='Vehicle_type')
plt.show()

# %% [markdown]
# ### pie chart

# %%
palette_color = sns.color_palette('bright')

# %%
plt.pie(data=data,\
x=data.Vehicle_type.value_counts(),\
explode = [0.1, 0], \
colors=palette_color,\
labels=['Passenger', 'Car'],\
autopct='%1.1f%%');

# %% [markdown]
# ### Reg plot

# %%
sns.regplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ### Rel plot

# %%
sns.relplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands', size='Price_in_thousands')
plt.show();

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ### cat plot

# %%
sns.catplot(data = data, x = 'Vehicle_type', y= 'Sales_in_thousands')
plt.show();

# %% [markdown]
# ### Boxen plot

# %%
sns.boxenplot(data=data, y='Horsepower')
plt.show()

# %% [markdown]
# ### viloin plot

# %%
sns.violinplot(data=data, y='Horsepower')
plt.show()

# %%
sns.violinplot(data=data, y='Sales_in_thousands')
plt.show()

# %%
data.Sales_in_thousands.value_counts().sample(10)
# Out:
# 13.462     1
# 11.185     1
# 81.174     1
# 31.038     1
# 230.902    1
# 18.392     1
# 199.685    1
# 540.561    1
# 39.350     1
# 88.094     1
# Name: Sales_in_thousands, dtype: int64

# %% [markdown]
# ### joint plot

# %%
sns.jointplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands')
plt.show()

# %%
sns.jointplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands', kind='hex')
plt.show()

# %% [markdown]
# ### swarm plot

# %%
sns.swarmplot(data = data, x = 'Vehicle_type', y= 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(data=data)#,palette='husl')
plt.show()
