# %% [markdown]
# <a href="https://colab.research.google.com/github/GLORIA-png/testrepo/blob/main/_car_price_prediction_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # car price prediction

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./Car_sales.csv')
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.shape
# Out:
# (157, 16)

# %%
data.size
# Out:
# 2512

# %%
data.info()     #checking datatype of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data['Sales_in_thousands'].dtype
# Out:
# dtype('float64')

# %%
data.isnull().sum()       #checking the null values
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data.duplicated().sum()  #count the number of duplicated rows
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ###  1.count of manufactures

# %%
data.Manufacturer.value_counts()
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %% [markdown]
# ### 2. model with max sales in thousand

# %%
model_max_sales_in_thousand=data.groupby(['Model'])['Sales_in_thousands'].max().reset_index()
model_max_sales_in_thousand.nlargest(5,'Sales_in_thousands')
# Out:
#         Model  Sales_in_thousands
# 63   F-Series             540.561
# 62   Explorer             276.747
# 31      Camry             247.994
# 145    Taurus             245.815
# 12     Accord             230.902

# %% [markdown]
# #### manufacturer with max horse power

# %%
max_horse_power_manufacturer=data.groupby(['Manufacturer'])['Horsepower'].max().reset_index()
max_horse_power_manufacturer.nlargest(5,'Horsepower')
# Out:
#    Manufacturer  Horsepower
# 7         Dodge       450.0
# 5     Chevrolet       345.0
# 1          Audi       310.0
# 16   Mercedes-B       302.0
# 14        Lexus       300.0

# %% [markdown]
# ### max yr resale value model

# %%
max_resale_model = data.groupby('Model')['__year_resale_value'].max().reset_index()
max_resale_model.nlargest(2,'__year_resale_value')
# Out:
#              Model  __year_resale_value
# 33  Carrera Cabrio               67.550
# 34   Carrera Coupe               60.625

# %%
max_resale_model = data.groupby('Model')['__year_resale_value'].max().idxmax()
max_resale_model
# Out:
# 'Carrera Cabrio'

# %%
data.Sales_in_thousands.max()
# Out:
# 540.561

# %%
data.Sales_in_thousands.min()
# Out:
# 0.11

# %%
data.Sales_in_thousands.mean()
# Out:
# 52.99807643312102

# %%
data.Model.value_counts()
# Out:
# Neon          2
# Integra       1
# Cutlass       1
# Sentra        1
# Altima        1
#              ..
# Windstar      1
# Expedition    1
# Ranger        1
# F-Series      1
# S80           1
# Name: Model, Length: 156, dtype: int64

# %%
data.Model.unique()
# Out:
# array(['Integra', 'TL', 'CL', 'RL', 'A4', 'A6', 'A8', '323i', '328i',
#        '528i', 'Century', 'Regal', 'Park Avenue', 'LeSabre', 'DeVille',
#        'Seville', 'Eldorado', 'Catera', 'Escalade', 'Cavalier', 'Malibu',
#        'Lumina', 'Monte Carlo', 'Camaro', 'Corvette', 'Prizm', 'Metro',
#        'Impala', 'Sebring Coupe', 'Sebring Conv.', 'Concorde', 'Cirrus',
#        'LHS', 'Town & Country', '300M', 'Neon', 'Avenger', 'Stratus',
#        'Intrepid', 'Viper', 'Ram Pickup', 'Ram Wagon', 'Ram Van',
#        'Dakota', 'Durango', 'Caravan', 'Escort', 'Mustang', 'Contour',
#        'Taurus', 'Focus', 'Crown Victoria', 'Explorer', 'Windstar',
#        'Expedition', 'Ranger', 'F-Series', 'Civic', 'Accord', 'CR-V',
#        'Passport', 'Odyssey', 'Accent', 'Elantra', 'Sonata', 'I30',
#        'S-Type', 'Wrangler', 'Cherokee', 'Grand Cherokee', 'ES300',
#        'GS300', 'GS400', 'LS400', 'LX470', 'RX300', 'Continental',
# ...

# %%
data.Model.nunique()
# Out:
# 156

# %% [markdown]
# ### Avg sales in thousand for each manufacturer

# %%
manufacturer_mean_sales = data.groupby('Manufacturer')['Sales_in_thousands'].mean().reset_index()
manufacturer_mean_sales
# Out:
#    Manufacturer  Sales_in_thousands
# 0         Acura           19.751250
# 1          Audi           13.519000
# 2           BMW           15.501667
# 3         Buick           60.504750
# 4      Cadillac           22.435600
# 5     Chevrolet           61.596111
# 6      Chrysler           28.817286
# 7         Dodge           82.740818
# 8          Ford          183.875909
# 9         Honda          118.534800
# 10      Hyundai           45.775333
# 11     Infiniti           23.713000
# 12       Jaguar           15.467000
# 13         Jeep           97.717667
# 14        Lexus           17.807167
# 15      Lincoln           28.544667
# 16   Mercedes-B           13.013889
# 17      Mercury           39.666500
# 18   Mitsubishi           25.842143
# 19       Nissan           57.090714
# 20   Oldsmobile           29.831500
# 21     Plymouth           16.000250
# 22      Pontiac           61.755667
# 23      Porsche            4.042667
# 24         Saab           10.653000
# ...

# %%
data.Vehicle_type.unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %% [markdown]
# ### vehicle type with max price in thousand

# %%
vehicle_type_max_price = data.groupby('Vehicle_type')['Price_in_thousands'].max().reset_index()
vehicle_type_max_price
# Out:
#   Vehicle_type  Price_in_thousands
# 0          Car              60.105
# 1    Passenger              85.500

# %% [markdown]
# ### sum of price in thosand for each vehicle type

# %%
vehicle_type_sum_price = data.groupby('Vehicle_type')['Price_in_thousands'].sum().reset_index()
vehicle_type_sum_price
# Out:
#   Vehicle_type  Price_in_thousands
# 0          Car            1052.799
# 1    Passenger            3192.768

# %% [markdown]
# ### Max curb weight for each vehicle type

# %%
vehicle_type_max_curb_weight = data.groupby('Vehicle_type')['Curb_weight'].max().reset_index()
vehicle_type_max_curb_weight
# Out:
#   Vehicle_type  Curb_weight
# 0          Car        5.572
# 1    Passenger        4.133

# %% [markdown]
# ### Max price in thosand for each vehicle type

# %%
vehicle_type_max_price = data.groupby('Vehicle_type')['Price_in_thousands'].max().reset_index()
vehicle_type_max_price
# Out:
#   Vehicle_type  Price_in_thousands
# 0          Car              60.105
# 1    Passenger              85.500

# %% [markdown]
# ###  avg horse power for each manufacturer

# %%
manufacturer_avg_horsepower = data.groupby('Manufacturer')['Horsepower'].mean().reset_index()
manufacturer_avg_horsepower
# Out:
#    Manufacturer  Horsepower
# 0         Acura  200.000000
# 1          Audi  220.000000
# 2           BMW  185.333333
# 3         Buick  206.250000
# 4      Cadillac  256.000000
# 5     Chevrolet  171.111111
# 6      Chrysler  194.833333
# 7         Dodge  199.545455
# 8          Ford  170.090909
# 9         Honda  160.400000
# 10      Hyundai  126.666667
# 11     Infiniti  227.000000
# 12       Jaguar  240.000000
# 13         Jeep  168.333333
# 14        Lexus  245.833333
# 15      Lincoln  263.333333
# 16   Mercedes-B  232.222222
# 17      Mercury  163.833333
# 18   Mitsubishi  165.142857
# 19       Nissan  169.000000
# 20   Oldsmobile  190.000000
# 21     Plymouth  166.750000
# 22      Pontiac  185.000000
# 23      Porsche  272.333333
# 24         Saab  177.500000
# 25       Saturn  119.600000
# 26       Subaru  165.000000
# 27       Toyota  160.666667
# 28   Volkswagen  120.833333
# 29        Volvo  182.166667

# %% [markdown]
# ### model with curb weight > 5 and horse power>250

# %%
curb_weight_horse=data.query("Curb_weight>5.0 & Horsepower > 250 ")
curb_weight_horse
# Out:
#    Manufacturer      Model  Sales_in_thousands  __year_resale_value  \
# 18     Cadillac   Escalade              14.785                  NaN
# 78      Lincoln  Navigator              22.925                  NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18          Car              46.225          5.7       255.0      117.5
# 78          Car              42.660          5.4       300.0      119.0
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 18   77.0   201.2        5.572           30.0             15.0     4/17/2012
# 78   79.9   204.8        5.393           30.0             15.0    12/23/2012
#
#     Power_perf_factor
# 18         109.509117
# 78         123.972047

# %%
curb_weight_horse_power_model=curb_weight_horse_power['Model']
curb_weight_horse_power_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5aa83746fe3d> in <cell line: 1>()
# ----> 1 curb_weight_horse_power_model=curb_weight_horse_power['Model']
#       2 curb_weight_horse_power_model
#
# NameError: name 'curb_weight_horse_power' is not defined

# %% [markdown]
# ### toyoto with engine size >4.0

# %%
high_engine_size_toyota_vehicles = data.query("Engine_size > 4.0 & Manufacturer == 'Toyota'")
high_engine_size_toyota_vehicles
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 144       Toyota  Land Cruiser               9.835                34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 144   76.4   192.5        5.115           25.4             15.0     9/25/2011
#
#      Power_perf_factor
# 144         102.528984

# %% [markdown]
# ### engine_size >3.5 or  price in thousand >  50 and vehicle type=passenger

# %%
engine_size_price_thousand= data.query("Engine_size > 3.5 & Price_in_thousands > 50  & Vehicle_type=='Passenger'")
engine_size_price_thousand
# Out:
#    Manufacturer     Model  Sales_in_thousands  __year_resale_value  \
# 6          Audi        A8               1.380               39.000
# 39        Dodge     Viper               0.916               58.470
# 73        Lexus     LS400               6.375               40.375
# 94   Mercedes-B   S-Class              16.774               50.375
# 95   Mercedes-B  SL-Class               3.311               58.600
# 99   Mercedes-B     CL500               0.954                  NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 6     Passenger              62.000          4.2       310.0      113.0
# 39    Passenger              69.725          8.0       450.0       96.2
# 73    Passenger              54.005          4.0       290.0      112.2
# 94    Passenger              69.700          4.3       275.0      121.5
# 95    Passenger              82.600          5.0       302.0       99.0
# ...

# %% [markdown]
# ### model with engine size > 3.5 and curb weight > 5

# %%
eng_size_curb_weight = data.query("Engine_size > 3.5 & Curb_weight > 5")
eng_size_curb_weight
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 18      Cadillac      Escalade              14.785                  NaN
# 74         Lexus         LX470               9.126                  NaN
# 78       Lincoln     Navigator              22.925                  NaN
# 144       Toyota  Land Cruiser               9.835                34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18           Car              46.225          5.7       255.0      117.5
# 74           Car              60.105          4.7       230.0      112.2
# 78           Car              42.660          5.4       300.0      119.0
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 18    77.0   201.2        5.572           30.0             15.0     4/17/2012
# 74    76.4   192.5        5.401           25.4             15.0    10/30/2012
# ...

# %% [markdown]
# ### vehicle with fuel efficiency 20 and 25 price in thousand <25

# %%
fuel_efficiency = data.query("20 <= Fuel_efficiency <= 25  & Price_in_thousands < 25")
fuel_efficiency
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 10         Buick         Century              91.561               12.475
# 20     Chevrolet          Malibu             135.126               11.225
# 21     Chevrolet          Lumina              24.629               10.310
# 23     Chevrolet          Camaro              26.402               13.025
# 28      Chrysler   Sebring Coupe               7.854               12.360
# 29      Chrysler   Sebring Conv.              32.775               14.180
# 36         Dodge         Avenger               4.734               12.545
# 37         Dodge         Stratus              71.186               10.185
# 45         Dodge         Caravan             181.749               12.025
# 47          Ford         Mustang             113.369               12.760
# 48          Ford         Contour              35.068                8.835
# 49          Ford          Taurus             245.815               10.055
# ...

# %%
data.Curb_weight.max()
# Out:
# 5.572

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ### model with most sales in thousand

# %%
model_most_sales_price=data.groupby(['Model'])['Sales_in_thousands'].max().reset_index()
model_most_sales_price.nlargest(5,'Sales_in_thousands')
# Out:
#         Model  Sales_in_thousands
# 63   F-Series             540.561
# 62   Explorer             276.747
# 31      Camry             247.994
# 145    Taurus             245.815
# 12     Accord             230.902
